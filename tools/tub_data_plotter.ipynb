# %% [markdown]
# # Displaying tub data as graphics
# Enter the path to your car directory and the tub you want to plot from.

# %%
path = '/Users/dirk/mycar2'
tub_id = 283

# %% [markdown]
# This find the tub through pattern matching and returns the first one, if there are multiple.

# %%
import glob
tub_path = glob.glob(path + '/data/tub_' + str(tub_id) + '*')[0]
print(tub_path)
# Out:
# /Users/dirk/mycar2/data/tub_283_19-10-22

# %% [markdown]
# This loads the tub through donkey.

# %%
import donkeycar as dk
from donkeycar.parts.datastore import Tub
cfg = dk.load_config(path + '/config.py')
tub = Tub(tub_path)
# Out:
# loading config file: /Users/dirk/mycar2/config.py
# loading personal config over-rides...
# config loaded
# Tub exists: /Users/dirk/mycar2/data/tub_283_19-10-22

# %% [markdown]
# Inspect the tub dimension (rows = num records, columns = data entries in record_xxx.json file):

# %%
import pandas as pd
df = tub.get_df()
print('tub shape:', df.shape)
print('columns:', df.columns.values)
if 'user/throttle' in df.columns.values:
    df['user/throttle'] *= cfg.MAX_SPEED
# Out:
# tub shape: (8777, 7)
# columns: ['car/speed' 'user/angle' 'cam/image_array' 'car/lap' 'milliseconds'
#  'timestamp' 'user/throttle']

# %% [markdown]
# Here we plot the user speed vs the car speed by selecting the column numbers, here 0 and 6:

# %%
l = [0, 6]

# %% [markdown]
# Use plotly to graph the values interactively.

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = go.Figure()
t = df['timestamp']
for i in l:
    fig.add_trace(go.Scatter(x=t, y=df[df.columns.values[i]], name=df.columns.values[i]))
fig.update_layout(title_text='Donkey record of tub ' + str(tub_id),
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="aa0bb5a1-9d38-4c02-80ee-cac458d40f71" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa0bb5a1-9d38-4c02-80ee-cac458d40f71")) {
#                     Plotly.newPlot(
#                         'aa0bb5a1-9d38-4c02-80ee-cac458d40f71',
#                         [{"name": "car/speed", "type": "scatter", "x": ["2019-10-22 19:58:05.223167", "2019-10-22 19:58:05.273354", "2019-10-22 19:58:05.298455", "2019-10-22 19:58:05.323549", "2019-10-22 19:58:05.348649", "2019-10-22 19:58:05.373737", "2019-10-22 19:58:05.398851", "2019-10-22 19:58:05.423943", "2019-10-22 19:58:05.449036", "2019-10-22 19:58:05.474132", "2019-10-22 19:58:05.499225", "2019-10-22 19:58:05.524312", "2019-10-22 19:58:05.549415", "2019-10-22 19:58:05.574502", "2019-10-22 19:58:05.599589", "2019-10-22 19:58:05.624691", "2019-10-22 19:58:05.649785", "2019-10-22 19:58:05.674868", "2019-10-22 19:58:05.699967", "2019-10-22 19:58:05.725059", "2019-10-22 19:58:05.750148", "2019-10-22 19:58:05.775244", "2019-10-22 19:58:05.800408", "2019-10-22 19:58:05.826345", "2019-10-22 19:58:05.851466", "2019-10-22 19:58:05.876593", "2019-10-22 19:58:05.901724", "2019-10-22 19:58:05.926845", "2019-10-22 19:58:05.952094", "2019-10-22 19:58:05.977223", "2019-10-22 19:58:06.002660", "2019-10-22 19:58:06.027765", "2019-10-22 19:58:06.052900", "2019-10-22 19:58:06.078249", "2019-10-22 19:58:06.103361", "2019-10-22 19:58:06.128738", "2019-10-22 19:58:06.154012",